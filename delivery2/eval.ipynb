# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import torch
from torch.utils.data import DataLoader
from transformers import AutoModelForSequenceClassification, AutoTokenizer, Trainer, TrainingArguments, \
    DataCollatorWithPadding
import pandas as pd
from sklearn.feature_extraction import text
from nltk.tokenize import word_tokenize

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)

# %%
model_path = "./roberta-base-ft"
# model_path = f'./roberta-1-epoch'
# model_path = f'./bert-domain-adapted-finetuned'
# model_path = f'./bert-base-uncased-ft'

# %%
orig_test_data = pd.read_json('../data/test_final.jsonl', lines=True)
test_data = pd.read_json('../data/test_final.jsonl', lines=True)
test_data = test_data.drop_duplicates(subset=['text'])

# %%
my_stop_words = text.ENGLISH_STOP_WORDS
words_to_keep = frozenset(['no', 'couldnt', 'cry', 'not', 'cant', 'cannot', 'nor', 'except', 'nobody',
                           'off', 'but', 'serious', 'enough', 'nothing', 'alone', 'down', 'only', 'without'])
my_stop_words = my_stop_words - words_to_keep

def pre_process_data(dataset):
    dataset['text'] = dataset['text'].apply(
        lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in my_stop_words])
    )
    return dataset

test_data = pre_process_data(test_data)

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSequenceClassification.from_pretrained(model_path, num_labels=6).to(device)

def tokenize_data(texts):
    return tokenizer(texts, padding='max_length', truncation=True, max_length=128)

class TextDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx], device=device) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx], device=device)
        return item

    def __len__(self):
        return len(self.labels)

# %%
test_encodings = tokenize_data(test_data['text'].tolist())
test_dataset = TextDataset(test_encodings, test_data['label'].tolist())

# %%
test_data
# Out:
#                                                    text  label
# 0     feel awful s job position succeed just didn t ...      0
# 1                                   im alone feel awful      0
# 2     ive probably mentioned but really feel proud a...      1
# 3                               feeling little low days      0
# 4     beleive sensitive peoples feelings tend compas...      2
# ...                                                 ...    ...
# 5395                   feel grumpy haven t yoga ed days      3
# 5396  read blog suburb direction mentioned casually ...      3
# 5397  not feel things realize violent physical suffe...      3
# 5398  feel petty silly giving shit but little things...      3
# 5399  remember feeling bitter couldnt pop balloons j...      3
#
# [5396 rows x 2 columns]

# %%
training_args = TrainingArguments(
    output_dir="./results",
    learning_rate=2e-5,
    per_device_train_batch_size=64,
    per_device_eval_batch_size=64,
    num_train_epochs=8,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
)

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    preds = np.argmax(predictions, axis=1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='weighted')
    acc = accuracy_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=test_dataset,
    eval_dataset=test_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

# %%
# trainer = Trainer(model=model)
# test_results = trainer.predict(test_dataset)
# print(test_results)

predictions = trainer.predict(test_dataset)
pred_labels = np.argmax(predictions.predictions, axis=-1)

# %%
emotions_to_int = {
    'sadness': 0,
    'joy': 1,
    'love': 2,
    'anger': 3,
    'fear': 4,
    'surprise': 5
}

int_to_emotions = {v: k for k, v in emotions_to_int.items()}

# %%
accuracy = accuracy_score(test_dataset.labels, pred_labels)
precision, recall, f1, _ = precision_recall_fscore_support(test_dataset.labels, pred_labels, average='macro')
conf_mat = confusion_matrix(test_dataset.labels, pred_labels)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-Score: {f1}")


sns.heatmap(conf_mat, annot=True, fmt='d', cmap='viridis', xticklabels=int_to_emotions.values(),
            yticklabels=int_to_emotions.values())
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# Accuracy: 0.9549666419570052
# Precision: 0.930629650714863
# Recall: 0.9679805849695996
# F1-Score: 0.9471757684766318

# %%
from sklearn.metrics import auc


def plot_multiclass_roc(y_pred, y_test, n_classes, figsize=(17, 6)):
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    y_test = np.eye(n_classes)[y_test]
    y_pred = np.eye(n_classes)[y_pred]

    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    plt.figure(figsize=figsize)
    plt.plot([0, 1], [0, 1], 'k--')
    for i in range(n_classes):
        plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f) for label %i' % (roc_auc[i], i))
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curve')
    plt.legend(loc="best")
    plt.show()
    
plot_multiclass_roc(pred_labels, test_dataset.labels, n_classes=6)

# %%
plt.clf()
conf_matrix = confusion_matrix(test_dataset.labels, pred_labels)
conf_matrix_copy = conf_matrix.copy()
for i in range(conf_matrix.shape[0]):
    conf_matrix[i, i] = 0 # make the diagonal null, to not eclipse the other values
    
plt.imshow(conf_matrix, cmap='viridis', interpolation='nearest')
# remove plot grid
plt.grid(False)
# annotate the axes with the emotion names
plt.xticks(range(6), int_to_emotions.values(), rotation=45)
plt.yticks(range(6), int_to_emotions.values())
# add colorbar more to the right
plt.colorbar()
# legend the axes with predicted and true values
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
# add counts in the plot
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        if i == j:
            plt.text(j, i, conf_matrix_copy[i, j], ha='center', va='center', color='black')
        else:
            plt.text(j, i, conf_matrix[i, j], ha='center', va='center', color='black')

for i in range(conf_matrix.shape[0]): # this does not count correct predictions
    plt.text(7, i, conf_matrix[i, :].sum(), ha='center', va='center', color='black')
for i in range(conf_matrix.shape[1]):
    plt.text(i, 7, conf_matrix[:, i].sum(), ha='center', va='center', color='black')
plt.show()

# %% [markdown]
# ## JOY classified as LOVE

# %%
# Assuming test_dataset.labels contains the true labels
true_labels = np.array(test_dataset.labels)
p_labels = np.array(pred_labels.tolist())

# %%
# Find indices where true label is 1 and predicted label is 2
indices = np.where((true_labels == 1) & (p_labels == 2))

# %%
# Get the elements from the dataset
[orig_test_data['text'][i] for i in indices[0]]
# Out:
# ['struggling awful feelings saying sweet things not deserving sisters friendship agreed car just starting drive away reached hand',
#  'write m sipping martini probably m feeling generous',
#  'really liked feeling beloved liked except hes away missed',
#  'feel blessed surrounded great coaches players administrators worked relentlessly dedicated institution',
#  'tend mouth shut im not enough informed but comes public education speak feel thats topic im passionate best',
#  'believed love lives feelings kind generous accepting exist independently decide not',
#  'didnt know but went home later experiment feel accepted but experimented learned new feeling feeling greed',
#  'love grapefruit macaron portrait feel gives feeing sweet but terrible taste like grapefruit just like macaron just looks like pretty cookie but complex',
#  'say catholics immediately scouting feeling wont long harder accepted scouting openly catholic openly gay',
#  'thankful people inner circle friends family mean world feel blessed beautiful souls life',
#  'cant feel blessed happy awesome sweet friends world whore',
#  'only seen chungking express feel like director make faithful film adaptation terms not only story but concepts themes',
#  'feel not title need ideas sweet',
#  'feel truly blessed path',
#  'feel gracious sitting typing hear sounds family sleeping',
#  'not happy simmons expressed feels goes laws nature men faithful marry men marry only response female manipulation',
#  'remember gold dust not willy wonka style gold tickets but m feeling generous liked new faceplate redesign just didn t work',
#  'feel watching beloved characters misery self destruction treated inherently funny',
#  'feel generous giving c',
#  'feeling generous capella version',
#  'checked national press associated media feel need crush rumours doing rounds regarding whereabouts beloved beardy hero',
#  'trust power feel passionate alive creative curious generous outraged injustice moved thoughtful action willing risks',
#  'chose live life normal person feelings wants desires talked faithful determined treated dignity respect',
#  'develops relationship lord feels attachment considers dearly beloved',
#  'feel faith faithful tradition',
#  'just feeling blessed compared',
#  'noticed couldn t feel razor glide shin ledge supporting foot',
#  'im not feeling generous',
#  'want love work feel passionate but want love home life equally',
#  'feel passionate technology',
#  'feel incredibly blessed able new personal challenge allow kids hold lot comfort zone',
#  'say mustve feeling generous caved',
#  'grew sense feelings source sweet lovable sheep',
#  'not feel like going harinama going book distribution going mangala arati but telling krishna not feel like doing but doing really sweet',
#  'look takes care feel blessed know babies going amazing father world',
#  'need feel beloved',
#  'hope love doesn t make feel like not beloved gloved anna loved sleep good drugs bad world without',
#  'feel passionate team feels passionate',
#  'going feel sweet release forgiveness tolerance extra laps',
#  'love game love feeling zone love feeling faithful remain true brain model',
#  'love types music feel truly passionate',
#  'purchase feel passionate toy making process',
#  'feel strongly supporting school teachers',
#  'shared earlier m working book adhd inattentive type ve lived feel passionate',
#  'feel like admired',
#  'feel need sweet night used end late night run ice dream oreo cookies grocery store down street',
#  'feel like going fab year',
#  'feel rebellious walking street',
#  'im feeling bit shaken but ill live',
#  'feel stupid worked',
#  'feel pathetic depend happiness',
#  'feel vital',
#  'stop talking start feel longing regret',
#  'feel lucky href http',
#  'feeling foolish taking lb e',
#  'haven t short hair long time feeling curious',
#  'feel angry sad',
#  'prayed prayed pregnant christmas but wasnt feeling hopeful december approached',
#  'im feeling need read lovely picture filled post areas state remind',
#  'im feeling impatient buying house thing',
#  'want ask thinks im selfish but im worried hell perceive accusation thing want think feel hostile',
#  'feel wronged frankly',
#  'remember feeling drained halfway shoot',
#  'feel hated dont know begin fix things',
#  'feel smug drive not only saving money but helping environment',
#  'didnt feel crappy immediately ive only started feeling chubby slow months',
#  'knew day coming but nothing really prepared id feel bit hesitant handing resignation letter',
#  'feel gives lovely natural peachy flush',
#  'goal fight but fluctuate bored lazy feel im not doing worthwhile',
#  'hours spend not make feel life tragic cruel',
#  'im trying feel whats acceptable community',
#  'grew feeling rejected lived head',
#  'feel accepted listened',
#  'ive largely getting plenty rest feeling horrible lol',
#  'away feel alone cycle begins',
#  'feel pathetic crying eric doesn t know',
#  'feel like missed school brain craving knowledge form',
#  'not embrace sin celebrate merely feel accepted loved',
#  'feel terrible terrible',
#  'need past feeling im selfish time',
#  'feel discontent life ve decided haphazardly scribble down course action crap want buy make notebook acquire plan attack',
#  'feel tell heartless',
#  'far received college degree actually sat down thought want achieve life feel embarrassed hears m not doing moment',
#  'feeling quite delicate abstained pork favour vegetarian option pasta chunks fried chicken',
#  'knew coming ways time meet probably billion years later but couldnt help feeling bitter',
#  'feel innocent intentions right',
#  'able just forge ahead life without hesitations second guessing feeling inadequate',
#  'say consider question life solar systems insignificant feel sure distraction people think important',
#  'told nurse feeling urge push extremely strong checked fully dilated ready deliver',
#  'feeling quite melancholy blue down dumps morose',
#  'feel bit listless',
#  'feel like im bit whiney but dont think unreasonable expect high class jeweler make custom piece ordered',
#  'feel like im dont care phase but know come weekend im gon na devastated',
#  'didnt feel afraid know knew not home believed spaceship',
#  'oso feeling way r juz tooo greedy',
#  'really feel women lives royally fucked dadt just like feel women sexually violated men women communities destroyed warring men',
#  'feel envious having babies not',
#  'feel free really better href http',
#  'mother person sharing housing accused trying rip off payment bills house',
#  'got rid locks wake feel amazing',
#  'feel crammed rushed not really im doing feel lost moving doing things',
#  'say feel invigorated optomistic hopeful just doesn t match innate senses',
#  'enjoy company new friend but feel isnt but developed feelings just']

# %% [markdown]
# ## JOY classified as SADNESS

# %%
indices = np.where((true_labels == 1) & (p_labels == 0))

# %%
[orig_test_data['text'][i] for i in indices[0]]
# Out:
# ['i feel that al gore is sincere in his beliefs but he is wasting his time',
#  'i wasnt feeling very well so i just stood aside amp let people fall',
#  'i know when you think of the name buck you think of a biker who has urine on his pants or your fishing buddy who doesn t say to much but that s because he is secretly smarter than you and he doesn t want you to feel like a moron by saying something intelligent',
#  'i used to feel super lonely when he was away',
#  'i respect the principle of her choice i cant help but feel betrayed by the seemingly casual disregard for my say in the matter',
#  'i repeat i dint scribble this to hurt anyones feelings if it looks so my sincere apologies for that dont take it personally if you hate it',
#  'id hurt someones feeling and it hurts me as well',
#  'i still look at their actions and feel badly about how well ive raised them',
#  'i feel grumpy a href http thegospelcoalition',
#  'im not certain why but being up so late when most of the city is quiet and sleeping makes me feel invigorated inspires me to better myself',
#  'i feel isolated and confused',
#  'i guess and i feel that now i am being punished for something that i may have done wrong',
#  'i suppose that right now i feel guilty',
#  'i just feel better in general']
